# %% [markdown]
# # Wikidataparsing

# %%
from src.dares import DARES

from src.model import ELIJERE

from src.utils import loadCorpus, prepare_corpus
from collections import Counter
# import json 

# import pandas as pd

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !python -m spacy download en_core_web_lg
# !python -m spacy download fr_core_news_lg
# !python -m spacy download en_core_web_trf
# !python -m spacy download fr_dep_news_trf

# %%
config_project = {
    "project_name": "Q5",
    "lg": "en",
    "spacy_model": "en_core_web_lg",
    "n_core": 6,
    "dares_parameters": {
        "item_limit": 1,
        "item_save_step": 20,
        "items_per_pages": 10,
        "source_doc": 'wikipedia',
        "score_cutoff": 95,
        "getOther": True,
        "maxsizesent": True,
        "removeNoMatch": True
    },
    "elijere_parameters": {
        "anchor_textvalue": ['lemma', 'pos'],
        "support": 0,
        "removePROPN": True
    },
    "entities":[
        {
            # specifiy by what Item type / Property must search in the WhatLinksHere pages (e.g. Q5 ('human'))
            "type": 'Q5',
            # you can provide a label for the Item / Property (e.g. 'human')
            "label": "human",
            # indicate the set of relations you want to collect from Wikidata / Wikipedia
            "props":{
                # PXX are the identifier of a Property on Wikidata
                # you define the label (e.g. placeOfBirth)
                "P19": {
                    "label": 'placeOfBirth',
                    "source": "Person",
                    "target": "Location"
                },
                "P119": {
                    "label": 'placeOfBurial',
                    "source": "Person",
                    "target": "Location"
                },
                "P569": {
                    "label": 'dateOfBirth',
                    "source": "Person",
                    "target": "Time"
                },
                "P570": {
                    "label": 'dateOfDeath',
                    "source": "Person",
                    "target": "Time"
                },
                "P509": {
                    "label": 'causeOfDeath',
                    "source": "Person",
                    "target": "Misc"
                },
                "P26": {
                    "label": 'spouse',
                    "source": "Person",
                    "target": "Person"
                },
                "P106": {
                    "label": 'occupation',
                    "source": "Person",
                    "target": "Misc"
                },
                "P69": {
                    "label": 'educatedAt',
                    "source": "Person",
                    "target": "Location"
                }
            }      
        }]
}

# %%
# below, example when collecting data for multiple entity types (here, person and location)
config_project = {
    [
        {
            "type": 'Q5',
            "name": "person",
            "props":{
                "P19": 'placeOfBirth',
                "P569": "dateOfBirth",
                "P509": 'causeOfDeath',
                "P570": "dateOfDeath",
                "P119": "placeOfBurial",
                "P26": "spouse",
                "P106": "occupation",
                "P69": "educatedAt",
                "P509": "causeOfDeath"
            }      
        },
        {   
            "type": "Property:P625",
            "name": "location",
            'props':{
                "P571": 'inception',
                "P17": "country",
                "P1082": "population",
                "P1376": "capitalOf",
                "P276": "location",
                "P36":"capital",
                "P35": "headOfState",
                "P6": "headOfGoverment",
                "P1082": "population",
                "P47": "sharesBordersWith",
                "P463": "memberOf",
                "P206": "nextInBodyWater"
            }
        }
    ]
}
projectname = f'test3'

wp.initiate_project(projectname, dict_rel)

# %% [markdown]
# # Build the DARES dataset

# %%
dares_config = config_project.copy()
del dares_config['elijere_parameters']
wp = DARES(**dares_config)

# %%
wp.collect_Wikidata_links()
# Out:
# Processing Q5 type...
# Starting from first url
# Done processing Q5 type
# Processing Q5 done
# projects/Q5

# %%
wp.processListEntities()
# Out:
# Step 1/6
# Collecting Entity data...
# Processing Q5 type...
# Processing Q5 done
# Entity data collected
# Step 2/6
# Collecting content...
# Content collected
# Step 3/6
# Collecting Entity labels...
# Entity labels collected
# Step 4/6
# Collecting properties...
# Properties collected
# Step 5/6
# Collecting sentences...
# Sentences collected
# Step 6/6
# Collecting Other sentences...
# Other sentences collected

# %%
# extracting shortest dependency path
corpus = wp.extract_sdp()
# Out:
# /Users/ngutehrl/miniconda3/envs/elijere/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(

# %%
# checks the distribution of relation in dataset
list_prop = [z['prop'] for x in corpus for y in x['content'] for z in y['props']]
# list_prop
Counter(list_prop).most_common()
# Out:
# [('dateOfBirth', 4), ('placeOfBirth', 3), ('dateOfDeath', 2), ('spouse', 1)]

# %% [markdown]
# # Build the Indices

# %%
# clean = True if you want to removes sentences annotated as Other
clean = True
corpus = loadCorpus(f"projects/{config_project['project_name']}", clean=clean)
len(corpus), corpus[0]
# Out:
# /Users/ngutehrl/miniconda3/envs/elijere/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:287: FutureWarning:
# The default value will be changed to `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_graph(data, edges="links") to preserve current behavior, or
#   nx.node_link_graph(data, edges="edges") for forward compatibility.
#   warnings.warn(
# (1,
#  {'id': 'Q23',
#   'content': [{'sent': "Based on his private papers and on accounts from his contemporaries, Washington slowly developed a cautious sympathy toward abolitionism that ended with his will freeing his long-time valet Billy Lee, and freeing the rest of his personally owned slaves outright upon Martha's death. On January 1, 1801, one year after George Washington's death, Martha Washington signed an order to free his slaves.",
#     'sent_i': 16,
#     'props': [{'prop': 'spouse',
#       'sent': "Based on his private papers and on accounts from his contemporaries, Washington slowly developed a cautious sympathy toward abolitionism that ended with his will freeing his long-time valet Billy Lee, and freeing the rest of his personally owned slaves outright upon Martha's death. On January 1, 1801, one year after George Washington's death, Martha Washington signed an order to free his slaves.",
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'Martha Washington',
#       'target_type': 'Person',
#       'sdpgraphs': [{'sourceNode': [58, 59],
#         'targetNode': [63, 64],
#         'sourceNodeRoot': 59,
#         'targetNodeRoot': 64,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02480>}]}],
#     'head': 65,
#     'graph': <networkx.classes.digraph.DiGraph at 0x16fa01880>},
#    {'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#     'sent_i': 30,
#     'props': [{'prop': 'dateOfBirth',
#       'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'February 22, 1732',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [3, 4, 5, 6],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 3,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa03080>}]},
#      {'prop': 'dateOfBirth',
#       'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': '1732',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [6],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 6,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02e40>}]},
#      {'prop': 'dateOfDeath',
#       'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'December 14, 1799',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [9, 10, 11, 12],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 9,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa01040>}]},
#      {'prop': 'dateOfDeath',
#       'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': '1799',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [12],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 12,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa017c0>}]}],
#     'head': 14,
#     'graph': <networkx.classes.digraph.DiGraph at 0x16c05e420>},
#    {'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_i': 31,
#     'props': [{'prop': 'placeOfBirth',
#       'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'Westmoreland County',
#       'target_type': 'Location',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [14, 15],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 15,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa032c0>}]},
#      {'prop': 'placeOfBirth',
#       'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'Westmoreland County, Virginia',
#       'target_type': 'Location',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [14, 15, 16, 17],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 15,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02150>}]},
#      {'prop': 'placeOfBirth',
#       'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'Westmoreland County, VA',
#       'target_type': 'Location',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [14, 15, 16],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 15,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa87710>}]},
#      {'prop': 'dateOfBirth',
#       'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': 'February 22, 1732',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [5, 6, 7, 8],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 5,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa87680>}]},
#      {'prop': 'dateOfBirth',
#       'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#       'source': 'George Washington',
#       'source_type': 'Person',
#       'target': '1732',
#       'target_type': 'Time',
#       'sdpgraphs': [{'sourceNode': [0, 1],
#         'targetNode': [8],
#         'sourceNodeRoot': 1,
#         'targetNodeRoot': 8,
#         'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa876b0>}]}],
#     'head': 3,
#     'graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>}]})

# %%
# Run this cell to convert the corpus in a format for building the indices
# also, allows to divide the corpus into a train, dev and validation test
params = {
    # corpus to process
    "corpus": corpus,
    # size of the train set. 1 means the whole corpus
    "train_size": 1,
    # size of the dev set
    "dev_size": 0,
    # removes Other labels
    "clean": True
    # "maxsize": 200000
}
data = prepare_corpus(**params)

try:
    print('Train size :',len(data['X_train']), 'Dev size :', len(data['X_dev']), 'Test size :',len(data['X_test']))
except:
    print('Train size :',len(data['X_train']))

c = Counter([y for y in data['y_train']])
print('Classes distribution : ', dict(c.most_common()))
# Out:
# Train size : 10
# Classes distribution :  {'dateOfBirth': 4, 'placeOfBirth': 3, 'dateOfDeath': 2, 'spouse': 1}

# %%
elijere = ELIJERE()

elijere_parameters = config_project['elijere_parameters']
elijere_parameters['data'] = data
elijere_parameters['savepath'] = f"projects/{config_project['project_name']}"

elijere_parameters
# Out:
# {'anchor_textvalue': ['lemma', 'pos'],
#  'support': 0,
#  'removePROPN': True,
#  'data': {'X_train': [{'sourceNode': [58, 59],
#     'targetNode': [63, 64],
#     'sourceNodeRoot': 59,
#     'targetNodeRoot': 64,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02480>,
#     'prop': 'spouse',
#     'source': 'George Washington',
#     'target': 'Martha Washington',
#     'sent': "Based on his private papers and on accounts from his contemporaries, Washington slowly developed a cautious sympathy toward abolitionism that ended with his will freeing his long-time valet Billy Lee, and freeing the rest of his personally owned slaves outright upon Martha's death. On January 1, 1801, one year after George Washington's death, Martha Washington signed an order to free his slaves.",
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16fa01880>,
#     'source_type': 'Person',
#     'target_type': 'Person'},
#    {'sourceNode': [0, 1],
#     'targetNode': [3, 4, 5, 6],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 3,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa03080>,
#     'prop': 'dateOfBirth',
#     'source': 'George Washington',
#     'target': 'February 22, 1732',
#     'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16c05e420>,
#     'source_type': 'Person',
#     'target_type': 'Time'},
#    {'sourceNode': [0, 1],
#     'targetNode': [6],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 6,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02e40>,
#     'prop': 'dateOfBirth',
#     'source': 'George Washington',
#     'target': '1732',
#     'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16c05e420>,
#     'source_type': 'Person',
#     'target_type': 'Time'},
#    {'sourceNode': [0, 1],
#     'targetNode': [9, 10, 11, 12],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 9,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa01040>,
#     'prop': 'dateOfDeath',
#     'source': 'George Washington',
#     'target': 'December 14, 1799',
#     'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16c05e420>,
#     'source_type': 'Person',
#     'target_type': 'Time'},
#    {'sourceNode': [0, 1],
#     'targetNode': [12],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 12,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa017c0>,
#     'prop': 'dateOfDeath',
#     'source': 'George Washington',
#     'target': '1799',
#     'sent': 'George Washington (February 22, 1732\xa0– December 14, 1799) was a Founding Father and the first president of the United States, serving from 1789 to 1797.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16c05e420>,
#     'source_type': 'Person',
#     'target_type': 'Time'},
#    {'sourceNode': [0, 1],
#     'targetNode': [14, 15],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 15,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa032c0>,
#     'prop': 'placeOfBirth',
#     'source': 'George Washington',
#     'target': 'Westmoreland County',
#     'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>,
#     'source_type': 'Person',
#     'target_type': 'Location'},
#    {'sourceNode': [0, 1],
#     'targetNode': [14, 15, 16, 17],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 15,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa02150>,
#     'prop': 'placeOfBirth',
#     'source': 'George Washington',
#     'target': 'Westmoreland County, Virginia',
#     'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>,
#     'source_type': 'Person',
#     'target_type': 'Location'},
#    {'sourceNode': [0, 1],
#     'targetNode': [14, 15, 16],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 15,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa87710>,
#     'prop': 'placeOfBirth',
#     'source': 'George Washington',
#     'target': 'Westmoreland County, VA',
#     'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>,
#     'source_type': 'Person',
#     'target_type': 'Location'},
#    {'sourceNode': [0, 1],
#     'targetNode': [5, 6, 7, 8],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 5,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa87680>,
#     'prop': 'dateOfBirth',
#     'source': 'George Washington',
#     'target': 'February 22, 1732',
#     'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>,
#     'source_type': 'Person',
#     'target_type': 'Time'},
#    {'sourceNode': [0, 1],
#     'targetNode': [8],
#     'sourceNodeRoot': 1,
#     'targetNodeRoot': 8,
#     'sdpgraph': <networkx.classes.digraph.DiGraph at 0x16fa876b0>,
#     'prop': 'dateOfBirth',
#     'source': 'George Washington',
#     'target': '1732',
#     'sent': 'George Washington was born on February 22, 1732, at Popes Creek in Westmoreland County, Virginia.',
#     'sent_graph': <networkx.classes.digraph.DiGraph at 0x16f6ca3c0>,
#     'source_type': 'Person',
#     'target_type': 'Time'}],
#   'y_train': ['spouse',
#    'dateOfBirth',
#    'dateOfBirth',
#    'dateOfDeath',
#    'dateOfDeath',
#    'placeOfBirth',
#    'placeOfBirth',
#    'placeOfBirth',
#    'dateOfBirth',
#    'dateOfBirth']},
#  'savepath': 'projects/Q5'}

# %%
elijere.fit(**elijere_parameters)
# Out:
# Building Syntactic Index...
# Building Syntactic Index done !
# Building Lexical Index...
# Building Lexical Index done !
# /Users/ngutehrl/miniconda3/envs/elijere/lib/python3.12/site-packages/networkx/readwrite/json_graph/node_link.py:142: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(

# %%
elijere.classifier.semanticIndex
# Out:
# CONCEPT-INDEX  dateOfBirth  dateOfDeath  placeOfBirth  spouse
# sign_VERB          0.00000          0.0      0.000000     1.0
# after_ADP          0.00000          0.0      0.000000     1.0
# death_NOUN         0.00000          0.0      0.000000     1.0
# 1732_NUM           1.00000          0.0      0.000000     0.0
# 1799_NUM           0.00000          1.0      0.000000     0.0
# bear_VERB          0.58696          0.0      0.809616     0.0
# at_ADP             0.00000          0.0      1.000000     0.0
# in_ADP             0.00000          0.0      1.000000     0.0
# on_ADP             1.00000          0.0      0.000000     0.0

# %%
elijere.extractFacts("Nicolas Gutehrkle was born on February 17, 1995 in Strasbourg")
# Out:
# [{'fact': {'pred': 'dateOfBirth',
#    'score': np.float64(0.8100023529280639),
#    'rule': 'semantic',
#    'anchor': 3,
#    'anchortext': 'bear_VERB',
#    'candidate': {'nodes': [1, 3, 4, 5, 6],
#     'labels': [{'name': 'dateOfBirth', 'support': 1}],
#     'graph': <networkx.classes.digraph.DiGraph at 0x3d5db6690>,
#     'source_types': ['Person'],
#     'source_nodes': [1],
#     'target_types': ['Time'],
#     'target_nodes': [6],
#     'ner_rules': {'dateOfBirth': {'source_type': 'Person',
#       'target_type': 'Time'}}}},
#   'ner': [{'pred': 'Person',
#     'root_node': 1,
#     'start': 1,
#     'end': 2,
#     'char_start': 8,
#     'char_end': 17},
#    {'pred': 'Time',
#     'root_node': 6,
#     'start': 6,
#     'end': 7,
#     'char_start': 39,
#     'char_end': 41}]},
#  {'fact': {'pred': 'dateOfBirth',
#    'score': np.float64(0.7397289709521384),
#    'rule': 'semantic',
#    'anchor': 3,
#    'anchortext': 'bear_VERB',
#    'candidate': {'nodes': [1, 10, 3, 9],
#     'labels': [{'name': 'dateOfBirth', 'support': 1}],
#     'graph': <networkx.classes.digraph.DiGraph at 0x3d5db69f0>,
#     'source_types': ['Person'],
#     'source_nodes': [1],
#     'target_types': ['Time'],
#     'target_nodes': [10],
#     'ner_rules': {'dateOfBirth': {'source_type': 'Person',
#       'target_type': 'Time'}}}},
#   'ner': [{'pred': 'Person',
#     'root_node': 1,
#     'start': 1,
#     'end': 2,
#     'char_start': 8,
#     'char_end': 17},
#    {'pred': 'Time',
#     'root_node': 10,
#     'start': 10,
#     'end': 11,
#     'char_start': 51,
#     'char_end': 61}]}]
